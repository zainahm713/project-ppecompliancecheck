# %% [markdown]
# # PPE Compliance Checker
# ### ITAI 1378 - Computer Vision Midterm Project
#
# **Team Members**
# - Eva Abou abou harb
# - Mary Ann Mastri
# - Zain Ahmed
#
# This notebook demonstrates the development of a PPE Compliance Checker using YOLO11 object detection to identify whether workers are wearing the required personal protective equipment.

# %% [markdown]
# ## 1. Install Dependencies
#
# Install the required Python packages and libraries needed for the project.

# %%
# Install the Ultralytics package
# !pip install -U ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.8/41.8 kB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 83.7 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## 2. Import Libraries
#
# Import the libraries used for data processing, model training, and visualization.

# %%
# Import required Libraries
from ultralytics import YOLO
import os
import yaml
import random
import cv2
import matplotlib.pyplot as plt
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %% [markdown]
# ## 3. Mount Google Drive
#
# Mount Google Drive to access the PPE dataset and project files.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Verify project folder
import os

project_path = "/content/drive/MyDrive/PPE_Compliance_Check"
os.listdir(project_path)
# Out:
# ['notebooks', 'presentations', 'datasets', 'results']

# %%
# Verify datasets folder
datasets_path = os.path.join(project_path, "datasets")
os.listdir(datasets_path)
# Out:
# ['kaggle_ppe', 'roboflow_ppe']

# %% [markdown]
# ## 4. Load Dataset
#
# Load the PPE dataset and verify that the files are correctly organized.

# %% [markdown]
# ## 5. Dataset Exploration
#
# Explore the dataset by displaying sample images and reviewing the available classes and labels.

# %% [markdown]
# ## 6. Train the YOLO11 Model
#
# Train or fine-tune the YOLO11 model using the selected PPE dataset.

# %% [markdown]
# ## 7. Evaluate the Model
#
# Evaluate the trained model using the selected performance metrics.

# %% [markdown]
# ## 8. Run Inference
#
# Test the trained model on new images and visualize the detection results.

# %% [markdown]
# ## 9. Results and Conclusion
#
# Summarize the model's performance and discuss key observations and possible improvements.
